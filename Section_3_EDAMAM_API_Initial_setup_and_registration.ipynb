# %% [markdown]
# # API requiring registration - POST request

# %% [markdown]
# ### Registering to the API

# %%
# We will use a nutritional analysis API
# It requires registration (we need an API key to validate ourselves)
# Many APIs require this kind of registration

# %%
# You can sign-up for the Developer (Free) edition here: 
#        https://developer.edamam.com/edamam-nutrition-api

# API documentation: 
#        https://developer.edamam.com/edamam-docs-nutrition-api

# %% [markdown]
# ### Initial Setup

# %%
# loading the packages
import requests
import json

# %%
# Store the ID and Key in variables

APP_ID = "b92002f0"
APP_KEY = "ed83d352b138dc57bd52adfc3320b428"

# %%
# Setting up the request URL
api_endpoint = "https://api.edamam.com/api/nutrition-details"

url = api_endpoint + "?app_id=" + APP_ID + "&app_key=" + APP_KEY

# %%
url #https://api.edamam.com/api/nutrition-details?app_id=b92002f0&app_key=ed83d352b138dc57bd52adfc3320b428
# Out:
# 'https://api.edamam.com/api/nutrition-details?app_id=b92002f0&app_key=ed83d352b138dc57bd52adfc3320b428'

# %%
#Sending a POST request

headers = {"Accept": "application/json"}

# %%
recipe = {"title":"Cappucino","ingr":["18g ground espresso","150mL Milk"]}

# %%
r = requests.post(url, headers=headers, json=recipe)
r.status_code
# Out:
# 200

# %%
cappucino = r.json()
print(json.dumps(cappucino, indent=4))
# Out:
# {
#     "uri": "http://www.edamam.com/ontologies/edamam.owl#recipe_13ddf88d0cd7424cb12ee083d4c41879",
#     "yield": 2.0,
#     "calories": 95,
#     "totalWeight": 172.69915386093172,
#     "dietLabels": [
#         "LOW_SODIUM"
#     ],
#     "healthLabels": [
#         "LOW_FAT_ABS",
#         "SUGAR_CONSCIOUS",
#         "LOW_POTASSIUM",
#         "KIDNEY_FRIENDLY",
#         "KETO_FRIENDLY",
#         "VEGETARIAN",
#         "PESCATARIAN",
#         "MEDITERRANEAN",
#         "GLUTEN_FREE",
#         "WHEAT_FREE",
#         "EGG_FREE",
#         "PEANUT_FREE",
#         "TREE_NUT_FREE",
#         "SOY_FREE",
#         "FISH_FREE",
#         "SHELLFISH_FREE",
#         "PORK_FREE",
#         "RED_MEAT_FREE",
#         "CRUSTACEAN_FREE",
#         "CELERY_FREE",
#         "MUSTARD_FREE",
#         "SESAME_FREE",
#         "LUPINE_FREE",
#         "MOLLUSK_FREE",
#         "ALCOHOL_FREE",
#         "NO_OIL_ADDED",
#         "NO_SUGAR_ADDED",
#         "SULPHITE_FREE",
#         "KOSHER"
#     ],
#     "cautions": [
#         "SULFITES"
#     ],
#     "totalNutrients": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 95.98648385516834,
#             "unit": "kcal"
#         },
#         "FAT": {
#             "label": "Total lipid (fat)",
#             "quantity": 5.060122500480281,
#             "unit": "g"
#         },
#         "FASAT": {
#             "label": "Fatty acids, total saturated",
#             "quantity": 2.9016992195063764,
#             "unit": "g"
#         },
#         "FATRN": {
#             "label": "Fatty acids, total trans",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "FAMS": {
#             "label": "Fatty acids, total monounsaturated",
#             "quantity": 1.2561571293507656,
#             "unit": "g"
#         },
#         "FAPU": {
#             "label": "Fatty acids, total polyunsaturated",
#             "quantity": 0.31822335002881685,
#             "unit": "g"
#         },
#         "CHOCDF": {
#             "label": "Carbohydrate, by difference",
#             "quantity": 7.726159385324722,
#             "unit": "g"
#         },
#         "CHOCDF.net": {
#             "label": "Carbohydrates (net)",
#             "quantity": 7.726159385324722,
#             "unit": "g"
#         },
#         "FIBTG": {
#             "label": "Fiber, total dietary",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "SUGAR": {
#             "label": "Sugars, total",
#             "quantity": 7.812307269977051,
#             "unit": "g"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 4.894623346619349,
#             "unit": "g"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 15.469915386093172,
#             "unit": "mg"
#         },
#         "NA": {
#             "label": "Sodium, Na",
#             "quantity": 69.04063616020063,
#             "unit": "mg"
#         },
#         "CA": {
#             "label": "Calcium, Ca",
#             "quantity": 175.17004386285285,
#             "unit": "mg"
#         },
#         "MG": {
#             "label": "Magnesium, Mg",
#             "quantity": 29.86991538609317,
#             "unit": "mg"
#         },
#         "K": {
#             "label": "Potassium, K",
#             "quantity": 224.90288309642986,
#             "unit": "mg"
#         },
#         "FE": {
#             "label": "Iron, Fe",
#             "quantity": 0.06980974615827952,
#             "unit": "mg"
#         },
#         "ZN": {
#             "label": "Zinc, Zn",
#             "quantity": 0.5813868692854474,
#             "unit": "mg"
#         },
#         "P": {
#             "label": "Phosphorus, P",
#             "quantity": 131.20728924318263,
#             "unit": "mg"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A, RAE",
#             "quantity": 71.1616107760286,
#             "unit": "\u00b5g"
#         },
#         "VITC": {
#             "label": "Vitamin C, total ascorbic acid",
#             "quantity": 0.036,
#             "unit": "mg"
#         },
#         "THIA": {
#             "label": "Thiamin",
#             "quantity": 0.07134161077602859,
#             "unit": "mg"
#         },
#         "RIBF": {
#             "label": "Riboflavin",
#             "quantity": 0.2933015700249746,
#             "unit": "mg"
#         },
#         "NIA": {
#             "label": "Niacin",
#             "quantity": 1.0749422469362293,
#             "unit": "mg"
#         },
#         "VITB6A": {
#             "label": "Vitamin B-6",
#             "quantity": 0.056051695389935416,
#             "unit": "mg"
#         },
#         "FOLDFE": {
#             "label": "Folate, DFE",
#             "quantity": 7.914957693046586,
#             "unit": "\u00b5g"
#         },
#         "FOLFD": {
#             "label": "Folate, food",
#             "quantity": 7.914957693046586,
#             "unit": "\u00b5g"
#         },
#         "FOLAC": {
#             "label": "Folic acid",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "VITB12": {
#             "label": "Vitamin B-12",
#             "quantity": 0.6961461923741927,
#             "unit": "\u00b5g"
#         },
#         "VITD": {
#             "label": "Vitamin D (D2 + D3)",
#             "quantity": 2.0110890001921122,
#             "unit": "\u00b5g"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E (alpha-tocopherol)",
#             "quantity": 0.1100894077026522,
#             "unit": "mg"
#         },
#         "VITK1": {
#             "label": "Vitamin K (phylloquinone)",
#             "quantity": 0.48209746158279515,
#             "unit": "\u00b5g"
#         },
#         "WATER": {
#             "label": "Water",
#             "quantity": 153.94036429763912,
#             "unit": "g"
#         }
#     },
#     "totalDaily": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 4.799324192758418,
#             "unit": "%"
#         },
#         "FAT": {
#             "label": "Fat",
#             "quantity": 7.78480384689274,
#             "unit": "%"
#         },
#         "FASAT": {
#             "label": "Saturated",
#             "quantity": 14.508496097531884,
#             "unit": "%"
#         },
#         "CHOCDF": {
#             "label": "Carbs",
#             "quantity": 2.5753864617749076,
#             "unit": "%"
#         },
#         "FIBTG": {
#             "label": "Fiber",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 9.789246693238699,
#             "unit": "%"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 5.156638462031057,
#             "unit": "%"
#         },
#         "NA": {
#             "label": "Sodium",
#             "quantity": 2.8766931733416934,
#             "unit": "%"
#         },
#         "CA": {
#             "label": "Calcium",
#             "quantity": 17.517004386285283,
#             "unit": "%"
#         },
#         "MG": {
#             "label": "Magnesium",
#             "quantity": 7.11188461573647,
#             "unit": "%"
#         },
#         "K": {
#             "label": "Potassium",
#             "quantity": 4.785167725455954,
#             "unit": "%"
#         },
#         "FE": {
#             "label": "Iron",
#             "quantity": 0.3878319231015529,
#             "unit": "%"
#         },
#         "ZN": {
#             "label": "Zinc",
#             "quantity": 5.285335175322249,
#             "unit": "%"
#         },
#         "P": {
#             "label": "Phosphorus",
#             "quantity": 18.743898463311805,
#             "unit": "%"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A",
#             "quantity": 7.906845641780954,
#             "unit": "%"
#         },
#         "VITC": {
#             "label": "Vitamin C",
#             "quantity": 0.039999999999999994,
#             "unit": "%"
#         },
#         "THIA": {
#             "label": "Thiamin (B1)",
#             "quantity": 5.945134231335716,
#             "unit": "%"
#         },
#         "RIBF": {
#             "label": "Riboflavin (B2)",
#             "quantity": 22.561659232690353,
#             "unit": "%"
#         },
#         "NIA": {
#             "label": "Niacin (B3)",
#             "quantity": 6.718389043351433,
#             "unit": "%"
#         },
#         "VITB6A": {
#             "label": "Vitamin B6",
#             "quantity": 4.311668876148878,
#             "unit": "%"
#         },
#         "FOLDFE": {
#             "label": "Folate equivalent (total)",
#             "quantity": 1.9787394232616464,
#             "unit": "%"
#         },
#         "VITB12": {
#             "label": "Vitamin B12",
#             "quantity": 29.0060913489247,
#             "unit": "%"
#         },
#         "VITD": {
#             "label": "Vitamin D",
#             "quantity": 13.407260001280749,
#             "unit": "%"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E",
#             "quantity": 0.733929384684348,
#             "unit": "%"
#         },
#         "VITK1": {
#             "label": "Vitamin K",
#             "quantity": 0.4017478846523293,
#             "unit": "%"
#         }
#     },
#     "ingredients": [
#         {
#             "text": "18g ground espresso",
#             "parsed": [
#                 {
#                     "quantity": 18.0,
#                     "measure": "gram",
#                     "foodMatch": "espresso",
#                     "food": "espresso",
#                     "foodId": "food_bwvztweawd5emqbcu3dqua2ts9ol",
#                     "weight": 18.0,
#                     "retainedWeight": 18.0,
#                     "nutrients": {
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.03186,
#                             "unit": "mg"
#                         },
#                         "VITD": {
#                             "label": "Vitamin D",
#                             "quantity": 0.0,
#                             "unit": "IU"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.00018,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 0.01656,
#                             "unit": "g"
#                         },
#                         "FATRN": {
#                             "label": "Fatty acids, total trans",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 0.93726,
#                             "unit": "mg"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 1.62,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 0.01656,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 0.036000000000000004,
#                             "unit": "mg"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 0.0216,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 0.0018,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 0.3006,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 0.0324,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.00036,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 17.604,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 20.7,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 1.26,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 2.52,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 0.009000000000000001,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 0.36,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 14.4,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 0.023399999999999997,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 0.018000000000000002,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 0.18,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 0.18,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_gram",
#                     "status": "OK"
#                 }
#             ]
#         },
#         {
#             "text": "150mL Milk",
#             "parsed": [
#                 {
#                     "quantity": 150.0,
#                     "measure": "milliliter",
#                     "foodMatch": "Milk",
#                     "food": "whole milk",
#                     "foodId": "food_b49rs1kaw0jktabzkg2vvanvvsis",
#                     "weight": 154.69915386093172,
#                     "retainedWeight": 154.69915386093172,
#                     "nutrients": {
#                         "VITD": {
#                             "label": "Vitamin D",
#                             "quantity": 78.89656846907518,
#                             "unit": "IU"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 94.36648385516835,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 2.8851392195063768,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 71.1616107760286,
#                             "unit": "\u00b5g"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 4.873023346619349,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 0.10828940770265222,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 15.46991538609317,
#                             "unit": "mg"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 7.425559385324721,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 5.027722500480281,
#                             "unit": "g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.2614415700249746,
#                             "unit": "mg"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.07116161077602859,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 0.30166335002881683,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 0.1376822469362292,
#                             "unit": "mg"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 1.2561571293507656,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.05569169538993541,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.6961461923741927,
#                             "unit": "\u00b5g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 136.3363642976391,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 204.20288309642987,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 129.94728924318264,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 66.52063616020064,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 0.5723868692854474,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total",
#                             "quantity": 7.812307269977051,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 174.81004386285284,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 15.46991538609317,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 0.04640974615827951,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 0.4640974615827951,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 7.734957693046585,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 7.734957693046585,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter",
#                     "status": "OK"
#                 }
#             ]
#         }
#     ],
#     "totalNutrientsKCal": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 97,
#             "unit": "kcal"
#         },
#         "PROCNT_KCAL": {
#             "label": "Calories from protein",
#             "quantity": 20,
#             "unit": "kcal"
#         },
#         "FAT_KCAL": {
#             "label": "Calories from fat",
#             "quantity": 46,
#             "unit": "kcal"
#         },
#         "CHOCDF_KCAL": {
#             "label": "Calories from carbohydrates",
#             "quantity": 31,
#             "unit": "kcal"
#         }
#     }
# }

# %%
cappucino.keys()
# Out:
# dict_keys(['uri', 'yield', 'calories', 'totalWeight', 'dietLabels', 'healthLabels', 'cautions', 'totalNutrients', 'totalDaily', 'ingredients', 'totalNutrientsKCal'])

# %%
print(json.dumps(cappucino['totalNutrients'], indent=4))
# Out:
# {
#     "ENERC_KCAL": {
#         "label": "Energy",
#         "quantity": 95.98648385516834,
#         "unit": "kcal"
#     },
#     "FAT": {
#         "label": "Total lipid (fat)",
#         "quantity": 5.060122500480281,
#         "unit": "g"
#     },
#     "FASAT": {
#         "label": "Fatty acids, total saturated",
#         "quantity": 2.9016992195063764,
#         "unit": "g"
#     },
#     "FATRN": {
#         "label": "Fatty acids, total trans",
#         "quantity": 0.0,
#         "unit": "g"
#     },
#     "FAMS": {
#         "label": "Fatty acids, total monounsaturated",
#         "quantity": 1.2561571293507656,
#         "unit": "g"
#     },
#     "FAPU": {
#         "label": "Fatty acids, total polyunsaturated",
#         "quantity": 0.31822335002881685,
#         "unit": "g"
#     },
#     "CHOCDF": {
#         "label": "Carbohydrate, by difference",
#         "quantity": 7.726159385324722,
#         "unit": "g"
#     },
#     "CHOCDF.net": {
#         "label": "Carbohydrates (net)",
#         "quantity": 7.726159385324722,
#         "unit": "g"
#     },
#     "FIBTG": {
#         "label": "Fiber, total dietary",
#         "quantity": 0.0,
#         "unit": "g"
#     },
#     "SUGAR": {
#         "label": "Sugars, total",
#         "quantity": 7.812307269977051,
#         "unit": "g"
#     },
#     "PROCNT": {
#         "label": "Protein",
#         "quantity": 4.894623346619349,
#         "unit": "g"
#     },
#     "CHOLE": {
#         "label": "Cholesterol",
#         "quantity": 15.469915386093172,
#         "unit": "mg"
#     },
#     "NA": {
#         "label": "Sodium, Na",
#         "quantity": 69.04063616020063,
#         "unit": "mg"
#     },
#     "CA": {
#         "label": "Calcium, Ca",
#         "quantity": 175.17004386285285,
#         "unit": "mg"
#     },
#     "MG": {
#         "label": "Magnesium, Mg",
#         "quantity": 29.86991538609317,
#         "unit": "mg"
#     },
#     "K": {
#         "label": "Potassium, K",
#         "quantity": 224.90288309642986,
#         "unit": "mg"
#     },
#     "FE": {
#         "label": "Iron, Fe",
#         "quantity": 0.06980974615827952,
#         "unit": "mg"
#     },
#     "ZN": {
#         "label": "Zinc, Zn",
#         "quantity": 0.5813868692854474,
#         "unit": "mg"
#     },
#     "P": {
#         "label": "Phosphorus, P",
#         "quantity": 131.20728924318263,
#         "unit": "mg"
#     },
#     "VITA_RAE": {
#         "label": "Vitamin A, RAE",
#         "quantity": 71.1616107760286,
#         "unit": "\u00b5g"
#     },
#     "VITC": {
#         "label": "Vitamin C, total ascorbic acid",
#         "quantity": 0.036,
#         "unit": "mg"
#     },
#     "THIA": {
#         "label": "Thiamin",
#         "quantity": 0.07134161077602859,
#         "unit": "mg"
#     },
#     "RIBF": {
#         "label": "Riboflavin",
#         "quantity": 0.2933015700249746,
#         "unit": "mg"
#     },
#     "NIA": {
#         "label": "Niacin",
#         "quantity": 1.0749422469362293,
#         "unit": "mg"
#     },
#     "VITB6A": {
#         "label": "Vitamin B-6",
#         "quantity": 0.056051695389935416,
#         "unit": "mg"
#     },
#     "FOLDFE": {
#         "label": "Folate, DFE",
#         "quantity": 7.914957693046586,
#         "unit": "\u00b5g"
#     },
#     "FOLFD": {
#         "label": "Folate, food",
#         "quantity": 7.914957693046586,
#         "unit": "\u00b5g"
#     },
#     "FOLAC": {
#         "label": "Folic acid",
#         "quantity": 0.0,
#         "unit": "\u00b5g"
#     },
#     "VITB12": {
#         "label": "Vitamin B-12",
#         "quantity": 0.6961461923741927,
#         "unit": "\u00b5g"
#     },
#     "VITD": {
#         "label": "Vitamin D (D2 + D3)",
#         "quantity": 2.0110890001921122,
#         "unit": "\u00b5g"
#     },
#     "TOCPHA": {
#         "label": "Vitamin E (alpha-tocopherol)",
#         "quantity": 0.1100894077026522,
#         "unit": "mg"
#     },
#     "VITK1": {
#         "label": "Vitamin K (phylloquinone)",
#         "quantity": 0.48209746158279515,
#         "unit": "\u00b5g"
#     },
#     "WATER": {
#         "label": "Water",
#         "quantity": 153.94036429763912,
#         "unit": "g"
#     }
# }

# %%
cappucino['totalNutrients']['SUGAR']
# Out:
# {'label': 'Sugars, total', 'quantity': 7.812307269977051, 'unit': 'g'}

# %%
#STRUCTURING AND EXPORTING DATA
import pandas as pd
capp_df = pd.DataFrame(cappucino['totalNutrients']).transpose()
capp_df
# Out:
#                                          label    quantity  unit
# ENERC_KCAL                              Energy   95.986484  kcal
# FAT                          Total lipid (fat)    5.060123     g
# FASAT             Fatty acids, total saturated    2.901699     g
# FATRN                 Fatty acids, total trans         0.0     g
# FAMS        Fatty acids, total monounsaturated    1.256157     g
# FAPU        Fatty acids, total polyunsaturated    0.318223     g
# CHOCDF             Carbohydrate, by difference    7.726159     g
# CHOCDF.net                 Carbohydrates (net)    7.726159     g
# FIBTG                     Fiber, total dietary         0.0     g
# SUGAR                            Sugars, total    7.812307     g
# PROCNT                                 Protein    4.894623     g
# CHOLE                              Cholesterol   15.469915    mg
# NA                                  Sodium, Na   69.040636    mg
# CA                                 Calcium, Ca  175.170044    mg
# MG                               Magnesium, Mg   29.869915    mg
# K                                 Potassium, K  224.902883    mg
# FE                                    Iron, Fe     0.06981    mg
# ZN                                    Zinc, Zn    0.581387    mg
# P                                Phosphorus, P  131.207289    mg
# VITA_RAE                        Vitamin A, RAE   71.161611    µg
# VITC            Vitamin C, total ascorbic acid       0.036    mg
# THIA                                   Thiamin    0.071342    mg
# RIBF                                Riboflavin    0.293302    mg
# NIA                                     Niacin    1.074942    mg
# VITB6A                             Vitamin B-6    0.056052    mg
# FOLDFE                             Folate, DFE    7.914958    µg
# FOLFD                             Folate, food    7.914958    µg
# FOLAC                               Folic acid         0.0    µg
# VITB12                            Vitamin B-12    0.696146    µg
# VITD                       Vitamin D (D2 + D3)    2.011089    µg
# TOCPHA            Vitamin E (alpha-tocopherol)    0.110089    mg
# VITK1                Vitamin K (phylloquinone)    0.482097    µg
# WATER                                    Water  153.940364     g

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
capp_df.to_csv("/content/drive/MyDrive/03 Web Scraping/Web Scraping and API Fundamentals in Python/Section 3/S3_L24/cappucino_nutrients.csv")

# %%
# ANOTHER REQUEST
recipe2 = {"title":"cheesecake","ingr":["16oz cream cheese","100g Sugar"]}

r = requests.post(url, headers=headers, json=recipe2)
r.status_code
# Out:
# 200

# %%
cheesecake = r.json()
print(json.dumps(cheesecake, indent=4))
# Out:
# {
#     "uri": "http://www.edamam.com/ontologies/edamam.owl#recipe_c40437b860c54988bc7dc19bbf1db818",
#     "yield": 8.0,
#     "calories": 1938,
#     "totalWeight": 553.5923700000001,
#     "dietLabels": [],
#     "healthLabels": [
#         "LOW_POTASSIUM",
#         "KIDNEY_FRIENDLY",
#         "VEGETARIAN",
#         "PESCATARIAN",
#         "GLUTEN_FREE",
#         "WHEAT_FREE",
#         "EGG_FREE",
#         "PEANUT_FREE",
#         "TREE_NUT_FREE",
#         "SOY_FREE",
#         "FISH_FREE",
#         "SHELLFISH_FREE",
#         "PORK_FREE",
#         "RED_MEAT_FREE",
#         "CRUSTACEAN_FREE",
#         "CELERY_FREE",
#         "MUSTARD_FREE",
#         "SESAME_FREE",
#         "LUPINE_FREE",
#         "MOLLUSK_FREE",
#         "ALCOHOL_FREE",
#         "NO_OIL_ADDED",
#         "KOSHER"
#     ],
#     "cautions": [
#         "SULFITES"
#     ],
#     "totalNutrients": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 1938.2859054000003,
#             "unit": "kcal"
#         },
#         "FAT": {
#             "label": "Total lipid (fat)",
#             "quantity": 155.31002748800003,
#             "unit": "g"
#         },
#         "FASAT": {
#             "label": "Fatty acids, total saturated",
#             "quantity": 87.50704002040001,
#             "unit": "g"
#         },
#         "FAMS": {
#             "label": "Fatty acids, total monounsaturated",
#             "quantity": 39.099662294,
#             "unit": "g"
#         },
#         "FAPU": {
#             "label": "Fatty acids, total polyunsaturated",
#             "quantity": 6.518122356900001,
#             "unit": "g"
#         },
#         "CHOCDF": {
#             "label": "Carbohydrate, by difference",
#             "quantity": 118.441209459,
#             "unit": "g"
#         },
#         "CHOCDF.net": {
#             "label": "Carbohydrates (net)",
#             "quantity": 118.441209459,
#             "unit": "g"
#         },
#         "FIBTG": {
#             "label": "Fiber, total dietary",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "SUGAR": {
#             "label": "Sugars, total",
#             "quantity": 114.360315077,
#             "unit": "g"
#         },
#         "SUGAR.added": {
#             "label": "Sugars, added",
#             "quantity": 99.8,
#             "unit": "g"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 26.898027541,
#             "unit": "g"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 498.9516070000001,
#             "unit": "mg"
#         },
#         "NA": {
#             "label": "Sodium, Na",
#             "quantity": 1656.6121505,
#             "unit": "mg"
#         },
#         "CA": {
#             "label": "Calcium, Ca",
#             "quantity": 445.52052260000005,
#             "unit": "mg"
#         },
#         "MG": {
#             "label": "Magnesium, Mg",
#             "quantity": 40.8233133,
#             "unit": "mg"
#         },
#         "K": {
#             "label": "Potassium, K",
#             "quantity": 627.9574706000001,
#             "unit": "mg"
#         },
#         "FE": {
#             "label": "Iron, Fe",
#             "quantity": 1.7736510060000004,
#             "unit": "mg"
#         },
#         "ZN": {
#             "label": "Zinc, Zn",
#             "quantity": 2.323321087,
#             "unit": "mg"
#         },
#         "P": {
#             "label": "Phosphorus, P",
#             "quantity": 480.80791220000003,
#             "unit": "mg"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A, RAE",
#             "quantity": 1660.1480742,
#             "unit": "\u00b5g"
#         },
#         "VITC": {
#             "label": "Vitamin C, total ascorbic acid",
#             "quantity": 0.0,
#             "unit": "mg"
#         },
#         "THIA": {
#             "label": "Thiamin",
#             "quantity": 0.09071847400000001,
#             "unit": "mg"
#         },
#         "RIBF": {
#             "label": "Riboflavin",
#             "quantity": 0.5859904625000001,
#             "unit": "mg"
#         },
#         "NIA": {
#             "label": "Niacin",
#             "quantity": 0.6577089365000001,
#             "unit": "mg"
#         },
#         "VITB6A": {
#             "label": "Vitamin B-6",
#             "quantity": 0.15875732950000004,
#             "unit": "mg"
#         },
#         "FOLDFE": {
#             "label": "Folate, DFE",
#             "quantity": 49.895160700000005,
#             "unit": "\u00b5g"
#         },
#         "FOLFD": {
#             "label": "Folate, food",
#             "quantity": 49.895160700000005,
#             "unit": "\u00b5g"
#         },
#         "FOLAC": {
#             "label": "Folic acid",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "VITB12": {
#             "label": "Vitamin B-12",
#             "quantity": 1.1339809250000001,
#             "unit": "\u00b5g"
#         },
#         "VITD": {
#             "label": "Vitamin D (D2 + D3)",
#             "quantity": 2.7215542200000002,
#             "unit": "\u00b5g"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E (alpha-tocopherol)",
#             "quantity": 1.3154178730000001,
#             "unit": "mg"
#         },
#         "VITK1": {
#             "label": "Vitamin K (phylloquinone)",
#             "quantity": 13.154178730000002,
#             "unit": "\u00b5g"
#         },
#         "WATER": {
#             "label": "Water",
#             "quantity": 246.95568622800002,
#             "unit": "g"
#         }
#     },
#     "totalDaily": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 96.91429527000001,
#             "unit": "%"
#         },
#         "FAT": {
#             "label": "Fat",
#             "quantity": 238.93850382769236,
#             "unit": "%"
#         },
#         "FASAT": {
#             "label": "Saturated",
#             "quantity": 437.5352001020001,
#             "unit": "%"
#         },
#         "CHOCDF": {
#             "label": "Carbs",
#             "quantity": 39.480403153,
#             "unit": "%"
#         },
#         "FIBTG": {
#             "label": "Fiber",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 53.796055082,
#             "unit": "%"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 166.31720233333337,
#             "unit": "%"
#         },
#         "NA": {
#             "label": "Sodium",
#             "quantity": 69.02550627083333,
#             "unit": "%"
#         },
#         "CA": {
#             "label": "Calcium",
#             "quantity": 44.55205226,
#             "unit": "%"
#         },
#         "MG": {
#             "label": "Magnesium",
#             "quantity": 9.719836500000001,
#             "unit": "%"
#         },
#         "K": {
#             "label": "Potassium",
#             "quantity": 13.360797246808513,
#             "unit": "%"
#         },
#         "FE": {
#             "label": "Iron",
#             "quantity": 9.853616700000002,
#             "unit": "%"
#         },
#         "ZN": {
#             "label": "Zinc",
#             "quantity": 21.12110079090909,
#             "unit": "%"
#         },
#         "P": {
#             "label": "Phosphorus",
#             "quantity": 68.68684460000001,
#             "unit": "%"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A",
#             "quantity": 184.46089713333333,
#             "unit": "%"
#         },
#         "VITC": {
#             "label": "Vitamin C",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "THIA": {
#             "label": "Thiamin (B1)",
#             "quantity": 7.559872833333334,
#             "unit": "%"
#         },
#         "RIBF": {
#             "label": "Riboflavin (B2)",
#             "quantity": 45.076189423076926,
#             "unit": "%"
#         },
#         "NIA": {
#             "label": "Niacin (B3)",
#             "quantity": 4.110680853125,
#             "unit": "%"
#         },
#         "VITB6A": {
#             "label": "Vitamin B6",
#             "quantity": 12.212102269230773,
#             "unit": "%"
#         },
#         "FOLDFE": {
#             "label": "Folate equivalent (total)",
#             "quantity": 12.473790175000001,
#             "unit": "%"
#         },
#         "VITB12": {
#             "label": "Vitamin B12",
#             "quantity": 47.24920520833334,
#             "unit": "%"
#         },
#         "VITD": {
#             "label": "Vitamin D",
#             "quantity": 18.143694800000002,
#             "unit": "%"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E",
#             "quantity": 8.769452486666667,
#             "unit": "%"
#         },
#         "VITK1": {
#             "label": "Vitamin K",
#             "quantity": 10.961815608333334,
#             "unit": "%"
#         }
#     },
#     "ingredients": [
#         {
#             "text": "16oz cream cheese",
#             "parsed": [
#                 {
#                     "quantity": 16.0,
#                     "measure": "ounce",
#                     "foodMatch": "cream cheese",
#                     "food": "cream cheese",
#                     "foodId": "food_a7rvc49a09a7yjbq3ekjbbauyoqa",
#                     "weight": 453.59237,
#                     "retainedWeight": 453.59237,
#                     "nutrients": {
#                         "VITD": {
#                             "label": "Vitamin D",
#                             "quantity": 113.3980925,
#                             "unit": "IU"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 1551.2859054,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 87.50704002040001,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 1660.1480741999999,
#                             "unit": "\u00b5g"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 26.898027541,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 1.3154178730000001,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 498.951607,
#                             "unit": "mg"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 18.461209459000003,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 155.310027488,
#                             "unit": "g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.5669904625000001,
#                             "unit": "mg"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.09071847400000001,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 6.518122356900001,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 0.6577089365000001,
#                             "unit": "mg"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 39.099662294,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.15875732950000002,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 1.1339809250000001,
#                             "unit": "\u00b5g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 246.935686228,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 625.9574706,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 480.8079122,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 1655.6121505,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 2.3133210870000003,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total",
#                             "quantity": 14.560315077,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 444.52052260000005,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 40.8233133,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 1.723651006,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 13.154178730000002,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 49.895160700000005,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 49.895160700000005,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_ounce",
#                     "status": "OK"
#                 }
#             ]
#         },
#         {
#             "text": "100g Sugar",
#             "parsed": [
#                 {
#                     "quantity": 100.0,
#                     "measure": "gram",
#                     "foodMatch": "Sugar",
#                     "food": "sugar",
#                     "foodId": "food_axi2ijobrk819yb0adceobnhm1c2",
#                     "weight": 100.0,
#                     "retainedWeight": 100.0,
#                     "nutrients": {
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.019,
#                             "unit": "mg"
#                         },
#                         "VITD": {
#                             "label": "Vitamin D",
#                             "quantity": 0.0,
#                             "unit": "IU"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 387.0,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 99.98,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "SUGAR.added": {
#                             "label": "Sugars, added",
#                             "quantity": 99.8,
#                             "unit": "g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 0.02,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 2.0,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 1.0,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 0.01,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total",
#                             "quantity": 99.8,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 1.0,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 0.05,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_gram",
#                     "status": "OK"
#                 }
#             ]
#         }
#     ],
#     "totalNutrientsKCal": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 1938,
#             "unit": "kcal"
#         },
#         "PROCNT_KCAL": {
#             "label": "Calories from protein",
#             "quantity": 105,
#             "unit": "kcal"
#         },
#         "FAT_KCAL": {
#             "label": "Calories from fat",
#             "quantity": 1369,
#             "unit": "kcal"
#         },
#         "CHOCDF_KCAL": {
#             "label": "Calories from carbohydrates",
#             "quantity": 464,
#             "unit": "kcal"
#         }
#     }
# }

# %%
cheesecake.keys()
# Out:
# dict_keys(['uri', 'yield', 'calories', 'totalWeight', 'dietLabels', 'healthLabels', 'cautions', 'totalNutrients', 'totalDaily', 'ingredients', 'totalNutrientsKCal'])

# %%
cheesecake['ingredients']
# Out:
# [{'text': '16oz cream cheese',
#   'parsed': [{'quantity': 16.0,
#     'measure': 'ounce',
#     'foodMatch': 'cream cheese',
#     'food': 'cream cheese',
#     'foodId': 'food_a7rvc49a09a7yjbq3ekjbbauyoqa',
#     'weight': 453.59237,
#     'retainedWeight': 453.59237,
#     'nutrients': {'VITD': {'label': 'Vitamin D',
#       'quantity': 113.3980925,
#       'unit': 'IU'},
#      'ENERC_KCAL': {'label': 'Energy',
#       'quantity': 1551.2859054,
#       'unit': 'kcal'},
#      'FASAT': {'label': 'Fatty acids, total saturated',
#       'quantity': 87.50704002040001,
#       'unit': 'g'},
#      'VITA_RAE': {'label': 'Vitamin A, RAE',
#       'quantity': 1660.1480741999999,
#       'unit': 'µg'},
#      'PROCNT': {'label': 'Protein', 'quantity': 26.898027541, 'unit': 'g'},
#      'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#       'quantity': 1.3154178730000001,
#       'unit': 'mg'},
#      'CHOLE': {'label': 'Cholesterol', 'quantity': 498.951607, 'unit': 'mg'},
#      'CHOCDF': {'label': 'Carbohydrate, by difference',
#       'quantity': 18.461209459000003,
#       'unit': 'g'},
#      'FAT': {'label': 'Total lipid (fat)',
#       'quantity': 155.310027488,
#       'unit': 'g'},
#      'FIBTG': {'label': 'Fiber, total dietary', 'quantity': 0.0, 'unit': 'g'},
#      'RIBF': {'label': 'Riboflavin',
#       'quantity': 0.5669904625000001,
#       'unit': 'mg'},
#      'THIA': {'label': 'Thiamin',
#       'quantity': 0.09071847400000001,
#       'unit': 'mg'},
#      'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#       'quantity': 6.518122356900001,
#       'unit': 'g'},
#      'NIA': {'label': 'Niacin', 'quantity': 0.6577089365000001, 'unit': 'mg'},
#      'VITC': {'label': 'Vitamin C, total ascorbic acid',
#       'quantity': 0.0,
#       'unit': 'mg'},
#      'FAMS': {'label': 'Fatty acids, total monounsaturated',
#       'quantity': 39.099662294,
#       'unit': 'g'},
#      'VITB6A': {'label': 'Vitamin B-6',
#       'quantity': 0.15875732950000002,
#       'unit': 'mg'},
#      'VITB12': {'label': 'Vitamin B-12',
#       'quantity': 1.1339809250000001,
#       'unit': 'µg'},
#      'WATER': {'label': 'Water', 'quantity': 246.935686228, 'unit': 'g'},
#      'K': {'label': 'Potassium, K', 'quantity': 625.9574706, 'unit': 'mg'},
#      'P': {'label': 'Phosphorus, P', 'quantity': 480.8079122, 'unit': 'mg'},
#      'NA': {'label': 'Sodium, Na', 'quantity': 1655.6121505, 'unit': 'mg'},
#      'ZN': {'label': 'Zinc, Zn', 'quantity': 2.3133210870000003, 'unit': 'mg'},
#      'SUGAR': {'label': 'Sugars, total',
#       'quantity': 14.560315077,
#       'unit': 'g'},
#      'CA': {'label': 'Calcium, Ca',
#       'quantity': 444.52052260000005,
#       'unit': 'mg'},
#      'MG': {'label': 'Magnesium, Mg', 'quantity': 40.8233133, 'unit': 'mg'},
#      'FE': {'label': 'Iron, Fe', 'quantity': 1.723651006, 'unit': 'mg'},
#      'VITK1': {'label': 'Vitamin K (phylloquinone)',
#       'quantity': 13.154178730000002,
#       'unit': 'µg'},
#      'FOLFD': {'label': 'Folate, food',
#       'quantity': 49.895160700000005,
#       'unit': 'µg'},
#      'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#      'FOLDFE': {'label': 'Folate, DFE',
#       'quantity': 49.895160700000005,
#       'unit': 'µg'}},
#     'measureURI': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#     'status': 'OK'}]},
#  {'text': '100g Sugar',
#   'parsed': [{'quantity': 100.0,
#     'measure': 'gram',
#     'foodMatch': 'Sugar',
#     'food': 'sugar',
#     'foodId': 'food_axi2ijobrk819yb0adceobnhm1c2',
#     'weight': 100.0,
#     'retainedWeight': 100.0,
#     'nutrients': {'RIBF': {'label': 'Riboflavin',
#       'quantity': 0.019,
#       'unit': 'mg'},
#      'VITD': {'label': 'Vitamin D', 'quantity': 0.0, 'unit': 'IU'},
#      'THIA': {'label': 'Thiamin', 'quantity': 0.0, 'unit': 'mg'},
#      'FAPU': {'label': 'Fatty acids, total polyunsaturated',
#       'quantity': 0.0,
#       'unit': 'g'},
#      'NIA': {'label': 'Niacin', 'quantity': 0.0, 'unit': 'mg'},
#      'ENERC_KCAL': {'label': 'Energy', 'quantity': 387.0, 'unit': 'kcal'},
#      'FASAT': {'label': 'Fatty acids, total saturated',
#       'quantity': 0.0,
#       'unit': 'g'},
#      'VITA_RAE': {'label': 'Vitamin A, RAE', 'quantity': 0.0, 'unit': 'µg'},
#      'VITC': {'label': 'Vitamin C, total ascorbic acid',
#       'quantity': 0.0,
#       'unit': 'mg'},
#      'PROCNT': {'label': 'Protein', 'quantity': 0.0, 'unit': 'g'},
#      'TOCPHA': {'label': 'Vitamin E (alpha-tocopherol)',
#       'quantity': 0.0,
#       'unit': 'mg'},
#      'CHOLE': {'label': 'Cholesterol', 'quantity': 0.0, 'unit': 'mg'},
#      'FAMS': {'label': 'Fatty acids, total monounsaturated',
#       'quantity': 0.0,
#       'unit': 'g'},
#      'CHOCDF': {'label': 'Carbohydrate, by difference',
#       'quantity': 99.98,
#       'unit': 'g'},
#      'FAT': {'label': 'Total lipid (fat)', 'quantity': 0.0, 'unit': 'g'},
#      'VITB6A': {'label': 'Vitamin B-6', 'quantity': 0.0, 'unit': 'mg'},
#      'VITB12': {'label': 'Vitamin B-12', 'quantity': 0.0, 'unit': 'µg'},
#      'SUGAR.added': {'label': 'Sugars, added', 'quantity': 99.8, 'unit': 'g'},
#      'FIBTG': {'label': 'Fiber, total dietary', 'quantity': 0.0, 'unit': 'g'},
#      'WATER': {'label': 'Water', 'quantity': 0.02, 'unit': 'g'},
#      'K': {'label': 'Potassium, K', 'quantity': 2.0, 'unit': 'mg'},
#      'P': {'label': 'Phosphorus, P', 'quantity': 0.0, 'unit': 'mg'},
#      'NA': {'label': 'Sodium, Na', 'quantity': 1.0, 'unit': 'mg'},
#      'ZN': {'label': 'Zinc, Zn', 'quantity': 0.01, 'unit': 'mg'},
#      'SUGAR': {'label': 'Sugars, total', 'quantity': 99.8, 'unit': 'g'},
#      'CA': {'label': 'Calcium, Ca', 'quantity': 1.0, 'unit': 'mg'},
#      'MG': {'label': 'Magnesium, Mg', 'quantity': 0.0, 'unit': 'mg'},
#      'FE': {'label': 'Iron, Fe', 'quantity': 0.05, 'unit': 'mg'},
#      'VITK1': {'label': 'Vitamin K (phylloquinone)',
#       'quantity': 0.0,
#       'unit': 'µg'},
#      'FOLFD': {'label': 'Folate, food', 'quantity': 0.0, 'unit': 'µg'},
#      'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#      'FOLDFE': {'label': 'Folate, DFE', 'quantity': 0.0, 'unit': 'µg'}},
#     'measureURI': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#     'status': 'OK'}]}]
